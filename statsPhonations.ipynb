# %%
# STATS
import pandas as pd
from pathlib import Path
import numpy as np
from scipy.io import wavfile
import os
import matplotlib.pyplot as plt
import pingouin as pg
import seaborn as sns
import scikit_posthocs as sp

groups = ["HC", "RBD", "PD", "MSA"]

variables = {
    "subharm_num": "Subharmonic cardinality",
    "subharm_per_second" : "Subharmonics per second",

    "subharm_sig_ratio": "Subharmonic-signal ratio",
    "density_num_slope" : "Number-density slope",
    "pct_subharm_num_2nd_half" : "Number-percentage in the second half", 
    "density_dur_slope": "Duration-density slope", 
    "pct_subharm_dur_2nd_half": "Duration-percentage in the second half",

    "first_occur": "First subharmonic occurence",
    "mean_inter_intervals": "Inter-subharmonic interval - mean", 
    "median_inter_intervals": "Inter-subharmonic interval - median",  
    "std_inter_intervals": "Inter-subharmonic interval - standard deviation",  
    "COV_inter_intervals": "Inter-subharmonic interval - CoV",
    
    "avg_dur": "Subharmonic duration - mean",
    "median_dur": "Subharmonic duration - median", 
    "std_dur": "Subharmonic duration - standard deviation", 
    "CV_dur": "Subharmonic duration - CoV", 
    "longest_dur": "Subharmonic duration - the longest",}

ylabels = ["Number of subharmonic components [-]", "Number of subharmonic components [-]",
"Subharmonic length:total signal length [-]", "NDS [-]", "NPSH [%]", "DDS [-]", "DPSH [%]",
"First subharmonic occcurence [s]", 
                        "Mean inter-subharmonic interval [s]", "Median inter-subharmonic interval [s]", 
                        "Std of inter-subharmonic intervals [s]", "CoV of inter-subharmonic intervals [s]",
"Mean subharmonic duration [s]", "Median subharmonic duration [s]", 
                          "Std of subharmonic durations [s]", "CoV of subharmonic durations [s]", "The longest subharmonic duration [s]",]



fontsize = 12

plt.rcParams.update({
    "font.family": "Times New Roman",
    "font.size": fontsize,
    "axes.titlesize": fontsize,
    "axes.labelsize": fontsize,
    "xtick.labelsize": fontsize,
    "ytick.labelsize": fontsize,
    "legend.fontsize": fontsize
})

# %%
df_phonations = pd.read_csv("compressed_phonation_features.csv")

df_phonations["group"] = df_phonations["group"].replace("PN", "PD")


fig, axes = plt.subplots(6, 3, figsize=(12, 19))
# fig, axes = plt.subplots(5, 4, figsize=(14, 22))
# fig, axes = plt.subplots(3, 6, figsize=(24, 12))
axes = axes.flatten()

for i, (var, ydata, title) in enumerate(zip(variables.keys(), ylabels, variables.values())):

    plot_var = var

    if var == "pct_subharm_num_2nd_half":
        df_phonations["temp_plot"] = df_phonations[var] * 100
        plot_var = "temp_plot"
    elif var == "pct_subharm_dur_2nd_half":
        df_phonations["temp_plot"] = df_phonations[var] * 100
        plot_var = "temp_plot"

    sns.boxplot(
        data=df_phonations,
        x="group",
        y=plot_var,
        order=groups,
        showfliers=False,
        ax=axes[i],
        width=0.4,
        linewidth=1
    )

    axes[i].set_title(title, fontweight="bold")
    axes[i].set_ylabel(ydata)
    axes[i].set_xlabel("Group")

# remove unused subplot
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.savefig("phonation_boxplots", dpi=300, bbox_inches="tight")
plt.show()

# %%
# STATS

posthoc_counter = 0
posthoc_results = []

fig, axes = plt.subplots(5, 3, figsize=(10, 17))
axes = axes.flatten()

for i, (dv, label) in enumerate(variables.items()):
    print("---------------------------------------------------------------")
    print(f"                     {label}")
    print("---------------------------------------------------------------")

    df_clean = df_phonations.dropna(subset=[dv]).copy()

    # group_medians = df_clean[df_clean[dv] != 0].groupby("group")[dv].median()
    # group_medians = df_clean.groupby("group")[dv].median()
    # print("\nGroup medians:")
    # print(group_medians)

    # group_means = df_clean.groupby("group")[dv].mean()
    # print("\nGroup means:")
    # print(group_means)
    # print()

    # Shapiro-Wilk normality test
    # norm_results = pg.normality(data=df_clean, dv=dv, group="group") # -> norm_results.normal
    # if norm_results.normal.all():
    #     print("NORMAL <<<<<<<<<<<<<<<<<<<<<<<<<")
    # else:
    #     print("NON-NORMAL <<<<<<<<<<<<<<<<<<<<<<<<<")

    # Levene homoscedasticity test
    # homo_results = pg.homoscedasticity(data=df_clean, dv=dv, group="group") # -> homo_results.equal_var
    # if homo_results.equal_var.iloc[0]:
    #     print("HOMO <<<<<<<<<<<<<<<<<<<<<<<<<")
    # else:
    #     print("NON-HOMO <<<<<<<<<<<<<<<<<<<<<<<<<")

    # KRUSKAL-WALLIS GROUP COMPARISON
    kw = pg.kruskal(data=df_clean, dv=dv, between="group")
    print(kw)
    H = kw["H"].values[0]
    k = len(groups)
    n = len(df_clean)
    print(f"N = {n}")
    eta_sq = (H-k+1)/(n-k)
    eps_sq = H/(n-1)
    print(f"Effect eta squared: {eta_sq:.4f}")
    print(f"Effect epsilon squared: {eps_sq:.4f}")

    # print("\nMean ranks")
    # df_clean["rank"] = df_clean[dv].rank()
    # mean_ranks = df_clean.groupby("group")["rank"].mean()
    # print(mean_ranks)

    pval = kw["p-unc"].values[0]
    # POST-HOC TEST
    if pval <= 0.05:
        posthoc_counter += 1
        show_cbar = False #(posthoc_counter % 2 == 0) #or (dv == "longest_dur")
        print()
        print("TIME FOR DUNN POST-HOC TEST")
        dunn = sp.posthoc_dunn(df_clean, val_col=dv, group_col="group", p_adjust="holm")
        print(dunn)
        dunn = dunn.loc[groups, groups]
        print(dunn)
        reject = (dunn < 0.05)

        posthoc_results.append({"counter": posthoc_counter, "label": label, "dunn": dunn.copy()})

        n_ticks = 6
        ticks_grey = np.round(np.linspace(0.05, 1.0, n_ticks), 1)   # 1.0 → 0.05
        ticks_color = np.linspace(0.0, 0.05, n_ticks)

        ax = axes[posthoc_counter - 1]
        # plt.figure(figsize=(8, 5))
        sns.heatmap(dunn, mask=reject, fmt=".3f", cmap='Greys_r', cbar=show_cbar, linewidths=0.5, alpha = 0.5, cbar_kws={"label": "p-value", "ticks": ticks_grey}, square=True, vmin=0.05, vmax=1.0, ax=ax)
        sns.heatmap(dunn, mask=~reject, fmt=".3f", cmap='coolwarm_r', cbar=show_cbar, linewidths=0.5, annot=True, annot_kws={"size": 12}, square=True, vmin=0.0, vmax=0.05, cbar_kws={"ticks": ticks_color}, ax=ax)
        
        if show_cbar:
            cbar = ax.collections[0].colorbar
            cbar.set_label("p-value", labelpad=15, fontsize=fontsize)
        # plt.title(f"{label}", fontsize=15, pad=15, fontweight="bold")
        ax.set_title(label, fontsize=fontsize, pad=10, fontweight="bold")
        # plt.savefig(f"posthoc/monolog/{label}_posthoc.png", dpi=300)
        # plt.show()
    
    print()

for j in range(posthoc_counter, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.savefig("posthoc_phonations_plot", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------
#                      Subharmonic cardinality
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  10.673669  0.013628
# N = 168
# Effect eta squared: 0.0468
# Effect epsilon squared: 0.0639
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.609078  0.815782  0.320539
# MSA  0.609078  1.000000  0.815782  0.015023
# PD   0.815782  0.815782  1.000000  0.049757
# RBD  0.320539  0.015023  0.049757  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.320539  0.815782  0.609078
# RBD  0.320539  1.000000  0.049757  0.015023
# PD   0.815782  0.049757  1.000000  0.815782
# MSA  0.609078  0.015023  0.815782  1.000000
#
# ---------------------------------------------------------------
#                      Subharmonics per second
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  14.262026  0.002569
# N = 168
# Effect eta squared: 0.0687
# Effect epsilon squared: 0.0854
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.182313  0.622626  0.320872
# MSA  0.182313  1.000000  0.622626  0.001828
# PD   0.622626  0.622626  1.000000  0.043389
# RBD  0.320872  0.001828  0.043389  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.320872  0.622626  0.182313
# RBD  0.320872  1.000000  0.043389  0.001828
# PD   0.622626  0.043389  1.000000  0.622626
# MSA  0.182313  0.001828  0.622626  1.000000
#
# ---------------------------------------------------------------
#                      Subharmonic-signal ratio
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  14.096993  0.002776
# N = 168
# Effect eta squared: 0.0677
# Effect epsilon squared: 0.0844
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.156729  0.513774  0.354136
# MSA  0.156729  1.000000  0.513774  0.001732
# PD   0.513774  0.513774  1.000000  0.063599
# RBD  0.354136  0.001732  0.063599  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.354136  0.513774  0.156729
# RBD  0.354136  1.000000  0.063599  0.001732
# PD   0.513774  0.063599  1.000000  0.513774
# MSA  0.156729  0.001732  0.513774  1.000000
#
# ---------------------------------------------------------------
#                      Number-density slope
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  4.492733  0.212939
# N = 168
# Effect eta squared: 0.0091
# Effect epsilon squared: 0.0269
#
# ---------------------------------------------------------------
#                      Number-percentage in the second half
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  9.311183  0.025427
# N = 168
# Effect eta squared: 0.0385
# Effect epsilon squared: 0.0558
#
# TIME FOR DUNN POST-HOC TEST
#            HC      MSA        PD       RBD
# HC   1.000000  1.00000  0.948327  0.288097
# MSA  1.000000  1.00000  1.000000  0.072040
# PD   0.948327  1.00000  1.000000  0.030524
# RBD  0.288097  0.07204  0.030524  1.000000
#            HC       RBD        PD      MSA
# HC   1.000000  0.288097  0.948327  1.00000
# RBD  0.288097  1.000000  0.030524  0.07204
# PD   0.948327  0.030524  1.000000  1.00000
# MSA  1.000000  0.072040  1.000000  1.00000
#
# ---------------------------------------------------------------
#                      Duration-density slope
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  7.907079  0.047972
# N = 168
# Effect eta squared: 0.0299
# Effect epsilon squared: 0.0473
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.797475  0.605466  0.605466
# MSA  0.797475  1.000000  0.453861  0.605466
# PD   0.605466  0.453861  1.000000  0.031613
# RBD  0.605466  0.605466  0.031613  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.605466  0.605466  0.797475
# RBD  0.605466  1.000000  0.031613  0.605466
# PD   0.605466  0.031613  1.000000  0.453861
# MSA  0.797475  0.605466  0.453861  1.000000
#
# ---------------------------------------------------------------
#                      Duration-percentage in the second half
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  8.840582  0.031487
# N = 168
# Effect eta squared: 0.0356
# Effect epsilon squared: 0.0529
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.983561  0.983561  0.337161
# MSA  0.983561  1.000000  0.983561  0.077257
# PD   0.983561  0.983561  1.000000  0.041012
# RBD  0.337161  0.077257  0.041012  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.337161  0.983561  0.983561
# RBD  0.337161  1.000000  0.041012  0.077257
# PD   0.983561  0.041012  1.000000  0.983561
# MSA  0.983561  0.077257  0.983561  1.000000
#
# ---------------------------------------------------------------
#                      First subharmonic occurence
# ---------------------------------------------------------------
#         Source  ddof1          H         p-unc
# Kruskal  group      3  36.641629  5.478986e-08
# N = 168
# Effect eta squared: 0.2051
# Effect epsilon squared: 0.2194
#
# TIME FOR DUNN POST-HOC TEST
#            HC           MSA        PD           RBD
# HC   1.000000  3.039279e-06  0.119070  6.537026e-01
# MSA  0.000003  1.000000e+00  0.007625  3.245115e-07
# PD   0.119070  7.624514e-03  1.000000  5.896847e-02
# RBD  0.653703  3.245115e-07  0.058968  1.000000e+00
#            HC           RBD        PD           MSA
# HC   1.000000  6.537026e-01  0.119070  3.039279e-06
# RBD  0.653703  1.000000e+00  0.058968  3.245115e-07
# PD   0.119070  5.896847e-02  1.000000  7.624514e-03
# MSA  0.000003  3.245115e-07  0.007625  1.000000e+00
#
# ---------------------------------------------------------------
#                      Inter-subharmonic interval - mean
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  0.889293  0.828011
# N = 60
# Effect eta squared: -0.0377
# Effect epsilon squared: 0.0151
#
# ---------------------------------------------------------------
#                      Inter-subharmonic interval - median
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  0.899977  0.825433
# N = 60
# Effect eta squared: -0.0375
# Effect epsilon squared: 0.0153
#
# ---------------------------------------------------------------
#                      Inter-subharmonic interval - standard deviation
# ---------------------------------------------------------------
#         Source  ddof1        H     p-unc
# Kruskal  group      3  8.79354  0.032166
# N = 45
# Effect eta squared: 0.1413
# Effect epsilon squared: 0.1999
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  1.000000  1.000000  0.150419
# MSA  1.000000  1.000000  1.000000  0.109832
# PD   1.000000  1.000000  1.000000  0.020643
# RBD  0.150419  0.109832  0.020643  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.150419  1.000000  1.000000
# RBD  0.150419  1.000000  0.020643  0.109832
# PD   1.000000  0.020643  1.000000  1.000000
# MSA  1.000000  0.109832  1.000000  1.000000
#
# ---------------------------------------------------------------
#                      Inter-subharmonic interval - CoV
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  10.066004  0.018013
# N = 45
# Effect eta squared: 0.1723
# Effect epsilon squared: 0.2288
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  1.000000  1.000000  0.102028
# MSA  1.000000  1.000000  1.000000  0.059657
# PD   1.000000  1.000000  1.000000  0.011099
# RBD  0.102028  0.059657  0.011099  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.102028  1.000000  1.000000
# RBD  0.102028  1.000000  0.011099  0.059657
# PD   1.000000  0.011099  1.000000  1.000000
# MSA  1.000000  0.059657  1.000000  1.000000
#
# ---------------------------------------------------------------
#                      Subharmonic duration - mean
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  11.807055  0.008074
# N = 168
# Effect eta squared: 0.0537
# Effect epsilon squared: 0.0707
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.347600  0.620399  0.303379
# MSA  0.347600  1.000000  0.620399  0.004889
# PD   0.620399  0.620399  1.000000  0.098272
# RBD  0.303379  0.004889  0.098272  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.303379  0.620399  0.347600
# RBD  0.303379  1.000000  0.098272  0.004889
# PD   0.620399  0.098272  1.000000  0.620399
# MSA  0.347600  0.004889  0.620399  1.000000
#
# ---------------------------------------------------------------
#                      Subharmonic duration - median
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  11.714926  0.008426
# N = 168
# Effect eta squared: 0.0531
# Effect epsilon squared: 0.0701
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.407192  0.674128  0.267519
# MSA  0.407192  1.000000  0.674128  0.005317
# PD   0.674128  0.674128  1.000000  0.090301
# RBD  0.267519  0.005317  0.090301  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.267519  0.674128  0.407192
# RBD  0.267519  1.000000  0.090301  0.005317
# PD   0.674128  0.090301  1.000000  0.674128
# MSA  0.407192  0.005317  0.674128  1.000000
#
# ---------------------------------------------------------------
#                      Subharmonic duration - standard deviation
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  7.854729  0.049111
# N = 60
# Effect eta squared: 0.0867
# Effect epsilon squared: 0.1331
#
# TIME FOR DUNN POST-HOC TEST
#           HC       MSA        PD      RBD
# HC   1.00000  0.594050  1.000000  1.00000
# MSA  0.59405  1.000000  0.055302  0.29374
# PD   1.00000  0.055302  1.000000  1.00000
# RBD  1.00000  0.293740  1.000000  1.00000
#           HC      RBD        PD       MSA
# HC   1.00000  1.00000  1.000000  0.594050
# RBD  1.00000  1.00000  1.000000  0.293740
# PD   1.00000  1.00000  1.000000  0.055302
# MSA  0.59405  0.29374  0.055302  1.000000
#
# ---------------------------------------------------------------
#                      Subharmonic duration - CoV
# ---------------------------------------------------------------
#         Source  ddof1         H     p-unc
# Kruskal  group      3  4.099435  0.250925
# N = 60
# Effect eta squared: 0.0196
# Effect epsilon squared: 0.0695
#
# ---------------------------------------------------------------
#                      Subharmonic duration - the longest
# ---------------------------------------------------------------
#         Source  ddof1          H     p-unc
# Kruskal  group      3  11.317565  0.010127
# N = 168
# Effect eta squared: 0.0507
# Effect epsilon squared: 0.0678
#
# TIME FOR DUNN POST-HOC TEST
#            HC       MSA        PD       RBD
# HC   1.000000  0.377564  0.708732  0.377564
# MSA  0.377564  1.000000  0.708732  0.006763
# PD   0.708732  0.708732  1.000000  0.098886
# RBD  0.377564  0.006763  0.098886  1.000000
#            HC       RBD        PD       MSA
# HC   1.000000  0.377564  0.708732  0.377564
# RBD  0.377564  1.000000  0.098886  0.006763
# PD   0.708732  0.098886  1.000000  0.708732
# MSA  0.377564  0.006763  0.708732  1.000000
