# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib qt
import pandas as pd
import seaborn as sns
from scipy.stats import norm
from pathlib import Path
import os
from scipy.io import wavfile
from pathlib import Path

# %%
datasheet = pd.read_csv("subharm_times.csv")

subharm_lens = datasheet["tmax"] - datasheet["tmin"]

# fit normal distribution
mu, std = norm.fit(subharm_lens)

# generate x values
x = np.linspace(subharm_lens.min(), subharm_lens.max(), 100)

# compute PDF
pdf = norm.pdf(x, mu, std)

# plot PDF curve
plt.figure()
# histogram (density=True makes it a PDF-like histogram)
plt.hist(subharm_lens, bins=20, density=True, alpha=0.6)
plt.plot(x, pdf)
plt.title("Histogram + PDF")
plt.xlabel("Subharm length [s]")
plt.ylabel("Density")
plt.show()

plt.figure()
sns.boxplot(data=datasheet, y=subharm_lens, showfliers=False)
plt.ylabel("Subharm length [s]")
plt.show()

print(f"Mean subharm length: {np.mean(subharm_lens):.3f}")
print(f"Median subharm length: {np.median(subharm_lens):.3f}")
print(f"Min subharm length: {np.min(subharm_lens):.3f}")
print(f"Max subharm length: {np.max(subharm_lens):.3f}")
# Out:
# Mean subharm length: 0.500
# Median subharm length: 0.233
# Min subharm length: 0.049
# Max subharm length: 10.404

# %%
def getSubharms(csv_path):
    if not os.path.isfile(csv_path):
        return None
    
    df = pd.read_csv(csv_path)        

    subharms = []

    a = False
    counter = 0
    for _, row in df.iterrows():
        counter += 1
        if row["text"] == "a":
            interval = (float(row["tmin"]), float(row["tmax"]))
            subharms.append(interval)
            a = True

    if counter > 1 and not a:
        print(f"---- PROBLEM WITH {csv_path}")

    return subharms


inter_subharm_intervals = []
groups = ["HC", "RBD", "PN", "MSA"]

for group in groups:

    folder_path = Path(group)/"prodlouzena_fonace"
    if folder_path.exists():
        for file_path in folder_path.iterdir():
            if file_path.is_file() and file_path.suffix.lower() == ".wav":

                sample_rate, data = wavfile.read(file_path)
                sample_name = file_path.stem

                csv_path = "labels/" + group + "/" + sample_name + ".csv"

                # Extract subharmonics
                subharms = getSubharms(csv_path)
                subharms = np.asarray(subharms, dtype=float)

                if subharms is None:
                    continue

                # ABSOLUTE NUMBER OF SUBHARMONICS IN THE SIGNAL
                subharm_total_no = len(subharms)

                # INTER-SUBHARMONIC INTERVALS      
                if subharm_total_no > 1: # at least 2 subharmonics for an interval
                    inter_intervals = subharms[1:, 0] - subharms[:-1, 1]
                    inter_subharm_intervals.extend(inter_intervals)


print(f"Min inter-subharm interval: {np.min(inter_subharm_intervals):.3f}")
print(f"Max inter-subharm interval: {np.max(inter_subharm_intervals):.3f}")
# Out:
# Min inter-subharm interval: 0.066
# Max inter-subharm interval: 22.532

# %%
def interpolate_pitch(pitch):
    pitch = pitch.copy()
    pitch = np.array(pitch)
    pitch[pitch <= 0] = np.nan
    valid = np.isfinite(pitch) & (pitch > 0)

    if np.sum(valid) < 2:
        return pitch

    pitch_interp = np.interp(
        np.arange(len(pitch)),
        np.where(valid)[0],
        pitch[valid]
    )

    return pitch_interp

def getFrameXt(pitch, frame_idx, n_side, fref_mode): # maybe test win_len: 100 ms, 150 ms, 200 ms, 300 ms

    win_start = frame_idx-n_side
    win_end = frame_idx+n_side
    # print(f"start: {win_start}, end: {win_end}")
    window_pitch = pitch[win_start:win_end+1]

    local_frame_idx = n_side
    if np.isnan(window_pitch[local_frame_idx]):
        return None
    
    window_pitch_valid = window_pitch[(~np.isnan(window_pitch)) & (window_pitch > 0)]
    # if len(window_pitch_valid) < 3:
    #     return None

    # print(window_pitch)
    # print(window_pitch_valid)
    
    if fref_mode == "upper_60_80_median":
        p60 = np.percentile(window_pitch_valid, 60)
        p80 = np.percentile(window_pitch_valid, 80)
        fref = np.median(window_pitch_valid[(window_pitch_valid >= p60) & (window_pitch_valid <= p80)])
    elif fref_mode == "upper_70_90_median":
        p70 = np.percentile(window_pitch_valid, 70)
        p90 = np.percentile(window_pitch_valid, 90)
        fref = np.median(window_pitch_valid[(window_pitch_valid >= p70) & (window_pitch_valid <= p90)])
    elif fref_mode == "upper_80_90_median":
        p80 = np.percentile(window_pitch_valid, 80)
        p90 = np.percentile(window_pitch_valid, 90)
        fref = np.median(window_pitch_valid[(window_pitch_valid >= p80) & (window_pitch_valid <= p90)])
    elif fref_mode == "median": # median
        fref = np.median(window_pitch_valid)
    else:
        raise ValueError("Unsupported fref_mode")
    
    # print(f"f_ref = {fref}")
    if not np.isfinite(fref) or fref <= 0:
        return None
    x_frame = np.log2(window_pitch[local_frame_idx]/fref)
    # print(np.log2(window_pitch/fref))
    # print(x_frame)
    return x_frame


def getXtFrames(pitch, first_frame_idx, last_frame_idx, n_side, fref_mode):
    x_frames = []
    for frame_idx in range(first_frame_idx, last_frame_idx+1):
        x_t = getFrameXt(pitch, frame_idx, n_side, fref_mode)
        if x_t is None:
            print("NONE")
        x_frames.append(x_t)
    
    return np.array(x_frames)

# %%
def gaussian_pdf(x, mu, sigma):
    sigma = max(float(sigma), 1e-6)
    return (1.0 / (np.sqrt(2.0 * np.pi) * sigma)) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)

def em_two_fixed_means(x_frames, prior_non_init, prior_sub_init, max_iter=200, tol=1e-4, sigma_floor=0.05,
                       mu_non=0.0, mu_sub=-1.0, sigma_non_init=0.15, sigma_sub_init=0.15,
                       ):
    
    x = np.asarray(x_frames, dtype=float)
    x = x[np.isfinite(x)]

    if x.size < 5:
        raise ValueError("Not enough valid x_t samples for EM.")

    prior_non = float(prior_non_init)
    prior_sub = float(prior_sub_init)
    sigma_non = max(float(sigma_non_init), sigma_floor)
    sigma_sub = max(float(sigma_sub_init), sigma_floor)

    prev_posterior_sub = None

    for i in range(max_iter):
        # print(f"ITERATION {i+1}")

        # E-step
        p_non = prior_non * gaussian_pdf(x, mu_non, sigma_non)
        p_sub = prior_sub * gaussian_pdf(x, mu_sub, sigma_sub)
      
        posterior_non = p_non / (p_non + p_sub + 1e-12)
        posterior_sub = p_sub / (p_non + p_sub + 1e-12)

        # convergence check right after E-step
        if prev_posterior_sub is not None:
            max_posterior_change = np.max(np.abs(posterior_sub - prev_posterior_sub))
            # print(f"max posterior change = {max_posterior_change:.5f}")

            if max_posterior_change < tol:
                # print(f"Stopping: max posterior change = {max_posterior_change:.5f}")
                break
        
        prev_posterior_sub = posterior_sub.copy()

        # M-step
        N_non = np.sum(posterior_non)
        N_sub = np.sum(posterior_sub)
        
        prior_non = N_non / x.size
        prior_sub = N_sub / x.size

        sigma_non = np.sqrt(np.sum(posterior_non * (x - mu_non) ** 2) / (N_non + 1e-12))
        sigma_non = max(float(sigma_non), sigma_floor)

        sigma_sub = np.sqrt(np.sum(posterior_sub * (x - mu_sub) ** 2) / (N_sub + 1e-12))
        sigma_sub = max(float(sigma_sub), sigma_floor)

        # print(
        #     f"prior_non={prior_non:.3f}, prior_sub={prior_sub:.3f}, "
        #     f"sigma_non={sigma_non:.4f}, sigma_sub={sigma_sub:.4f}"
        # )


    # final E-step with final parameters
    p_non = prior_non * gaussian_pdf(x, mu_non, sigma_non)
    p_sub = prior_sub * gaussian_pdf(x, mu_sub, sigma_sub)

    posterior_non = p_non / (p_non + p_sub + 1e-12)
    posterior_sub = p_sub / (p_non + p_sub + 1e-12)

    return {
        "prior_non": prior_non,
        "prior_sub": prior_sub,
        "mu_non": mu_non,
        "mu_sub": mu_sub,
        "sigma_non": sigma_non,
        "sigma_sub": sigma_sub,
        "posterior_non": posterior_non,
        "posterior_sub": posterior_sub,
    }

# %%
def smooth_posterior(posterior, win_len):
    """
    Simple moving average smoothing.
    win_len should usually be odd: 3, 5, 7...
    """
    posterior = np.asarray(posterior, dtype=float)

    if win_len <= 1:
        return posterior.copy()

    kernel = np.ones(win_len, dtype=float) / win_len
    posterior_smooth = np.convolve(posterior, kernel, mode="same")
    return posterior_smooth

def find_runs(labels):
    labels = np.asarray(labels, dtype=bool)
    runs = []

    if len(labels) == 0:
        return runs

    start = 0
    current = labels[0]

    for i in range(1, len(labels)):
        if labels[i] != current:
            runs.append((current, start, i - 1))
            start = i
            current = labels[i]

    runs.append((current, start, len(labels) - 1))
    return runs

def fill_short_gaps(labels, min_gap_frames):
    """
    If a zero-run between two positive runs is short enough,
    convert it to ones.
    """
    labels = np.asarray(labels, dtype=bool).copy()
    runs = find_runs(labels)

    for value, start, end in runs:
        run_len = end - start + 1

        if value == False and run_len <= min_gap_frames:
            left_is_sub = start > 0 and labels[start - 1]
            right_is_sub = end < len(labels) - 1 and labels[end + 1]

            if left_is_sub and right_is_sub:
                labels[start:end + 1] = True

    return labels

def remove_short_subharmonic_runs(labels, min_len_frames):
    """
    Remove positive runs that are shorter than min_len_frames.
    """
    labels = np.asarray(labels, dtype=bool).copy()
    runs = find_runs(labels)

    for value, start, end in runs:
        run_len = end - start + 1

        if value == True and run_len < min_len_frames:
            labels[start:end + 1] = False

    return labels

def labels_to_intervals(times, labels):
    intervals = []
    in_interval = False
    start_idx = None

    for i, lab in enumerate(labels):
        # Start of subharmonic interval reached
        if lab == True and in_interval == False:
            in_interval = True
            start_idx = i

        # End of subharmonic interval reached
        elif lab == False and in_interval == True:
            end_idx = i - 1
            intervals.append((times[start_idx], times[end_idx]))
            in_interval = False

    # Subharmonic till the end
    if in_interval:
        intervals.append((times[start_idx], times[len(labels) - 1]))

    return intervals

def predAndPostProcessFrames(posteriors, decision_thresh, time_step, min_gap_frames, min_len_frames):
    smooth_span_sec = 0.05
    smooth_win_len = int(round(smooth_span_sec / time_step))
    if smooth_win_len % 2 == 0:
        smooth_win_len += 1
    smooth_win_len = max(smooth_win_len, 1)
    # print(f"Smooth win len for 50ms: {smooth_win_len} frames")

    # print(em["posterior_sub"].shape)
    posterior_smoothed = smooth_posterior(posteriors, smooth_win_len)
    # print(posterior_smoothed.shape)
    # print(time_frames.shape)
    frame_preds = (posterior_smoothed >= decision_thresh)
    # print(labels_sub.sum())

    frame_preds = fill_short_gaps(frame_preds, min_gap_frames)
    # print(f"After 1st gap filling: {np.sum(labels_sub)}")
    frame_preds = remove_short_subharmonic_runs(frame_preds, min_len_frames)
    # print(f"After removing short runs: {np.sum(labels_sub)}")
    frame_preds = fill_short_gaps(frame_preds, min_gap_frames)
    # print(f"After 2nd gap filling: {np.sum(labels_sub)}")

    return frame_preds

# %%
def interval_iou(a, b):
    a_start, a_end = a
    b_start, b_end = b

    # intersection
    inter = max(0, min(a_end, b_end) - max(a_start, b_start))

    # union
    union = (a_end - a_start) + (b_end - b_start) - inter

    return inter / union if union > 0 else 0.0


def greedy_match_intervals(labels, preds, iou_threshold):
    """
    Greedy one-to-one matching of label intervals and predicted intervals.

    Args:
        labels: list of (start, end)
        preds: list of (start, end)
        iou_threshold: minimum IoU required to allow a match

    Returns:
        matches: list of dicts with matched pairs
        unmatched_labels: list of dicts
        unmatched_preds: list of dicts
    """
    candidates = []

    # Compute all candidate matches
    for li, label in enumerate(labels):
        for pi, pred in enumerate(preds):
            iou = interval_iou(label, pred)
            if iou >= iou_threshold:
                candidates.append((iou, li, pi))

    # Best IoU first
    candidates.sort(key=lambda x: x[0], reverse=True)

    matched_label_idxs = set()
    matched_pred_idxs = set()
    matches = []

    for iou, li, pi in candidates:
        if li in matched_label_idxs or pi in matched_pred_idxs:
            continue

        matches.append({
            "label_idx": li,
            "pred_idx": pi,
            "label": labels[li],
            "pred": preds[pi],
            "iou": iou,
        })
        matched_label_idxs.add(li)
        matched_pred_idxs.add(pi)

    unmatched_labels = [
        {"label_idx": li, "label": labels[li]}
        for li in range(len(labels))
        if li not in matched_label_idxs
    ]

    unmatched_preds = [
        {"pred_idx": pi, "pred": preds[pi]}
        for pi in range(len(preds))
        if pi not in matched_pred_idxs
    ]

    return matches, unmatched_labels, unmatched_preds

# %%
def detectSubharmonics(data, interval_labels, sample_length, tmin_cutoff, win_len, fref_mode, min_gap_dur, min_subharm_dur):

    # print(interval_labels)
    times = data[:, 0]
    pitch = data[:, 1]
    pitch = interpolate_pitch(pitch)

    if len(times) != len(pitch):
        raise IndexError("Time indeces don't match pitch values!")

    time_step = np.round(np.median(np.diff(times)), 4)

    # win_len = 0.25 # 250 ms
    n_side = int(round((win_len / 2) / time_step))
    # print(n_side)
    # print(np.searchsorted(times, 1, side='left'))
    # print(len(times) - n_side -1)
    # print(np.searchsorted(times, sample_length-1, side='right') - 1)
    first_frame_idx = max(n_side, np.searchsorted(times, tmin_cutoff, side='left')) # frame_idx = np.searchsorted(times, times[0] + win_len/2)
    last_frame_idx = min(len(times) - n_side -1, np.searchsorted(times, sample_length-tmin_cutoff, side='right') - 1)
    # win_size = 2*n_side + 1

    x_frames = getXtFrames(pitch, first_frame_idx, last_frame_idx, n_side, fref_mode)
    time_frames = times[first_frame_idx:last_frame_idx+1]

    prior_non_init, prior_sub_init = 0.9, 0.1
    em = em_two_fixed_means(x_frames, prior_non_init, prior_sub_init)   

    # min_subharm_dur = 0.05
    # max_gap_dur = 0.5

    min_len_frames = int(np.ceil(min_subharm_dur / time_step))
    min_gap_frames = int(np.floor(min_gap_dur / time_step))
    # print(f"min_len_frames = {min_len_frames}")
    # print(f"max_gap_frames = {max_gap_frames}")

    decision_thresh = 0.5
    # labels_sub = (em["posterior_sub"] >= decision_thresh)
    # print(labels_sub.sum())

    frame_preds = predAndPostProcessFrames(em["posterior_sub"], decision_thresh, time_step, min_gap_frames, min_len_frames)

    interval_preds = labels_to_intervals(time_frames, frame_preds)
    # print(f"Total number of subharmonic intervals: {len(intervals)}")

    iou_threshold = 0.3
    matches, unmatched_labels, unmatched_preds = greedy_match_intervals(interval_labels, interval_preds, iou_threshold)

    TP = len(matches)
    FN = len(unmatched_labels)
    FP = len(unmatched_preds)

    return TP, FP, FN

# %%
def getAccuracy(TP, FP, FN):
    return TP / (TP + FP + FN) if (TP) > 0 else 0.0

def getPrecision(TP, FP):
    return TP / (TP + FP) if (TP + FP) > 0 else 0.0

def getRecall(TP, FN):
    return TP / (TP + FN) if (TP + FN) > 0 else 0.0

def getF1(precision, recall):
    return 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

# %%
recording_lengths = {}  

groups = ["HC", "RBD", "PN", "MSA"]
for group in groups:
    folder_path = Path(group)/"prodlouzena_fonace"
    if folder_path.exists():
        for file_path in folder_path.iterdir():
            if file_path.is_file() and file_path.suffix.lower() == ".wav":

                fs, data = wavfile.read(file_path)
                sample_name = file_path.stem

                rec_duration = len(data)/fs
                recording_lengths[sample_name] = rec_duration


df_labels = pd.read_csv("subharm_times.csv")

# fix missing sample names
df_labels["sample"] = df_labels["sample"].ffill()

labels_intervals = {}
subharm_group_counts = {"HC": 0, "RBD": 0, "PN": 0, "MSA": 0}

for sample, group_df in df_labels.groupby("sample"):
    # intervals = list(zip(group_df["tmin"], group_df["tmax"]))
    rec_len = recording_lengths[sample]
    intervals = [
                (tmin, tmax)
                for tmin, tmax in zip(group_df["tmin"], group_df["tmax"])
                if (tmin > 1) and (tmin < rec_len - 1)
                ]

    group_name = group_df["group"].iloc[0]  # same for whole sample
    subharm_group_counts[group_name] += len(intervals)

    labels_intervals[sample] = intervals # "group": group_name,

print("Total number of subharmonic labels per group:")
for g, gc in subharm_group_counts.items():
    print(f"{g}: {gc}")
# Out:
# Total number of subharmonic labels per group:
# HC: 84
# RBD: 44
# PN: 144
# MSA: 198

# %%
# performance_metrics = {"HC": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
#                        "RBD": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
#                        "PN": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
#                        "MSA": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
#                        "overall": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},}

# FP_group_sample_counter = {"HC": 0, "RBD": 0, "PN": 0, "MSA": 0}
# top3_FP_per_group = {"HC": [(None, -np.inf), (None, -np.inf), (None, -np.inf)], 
#                      "RBD": [(None, -np.inf), (None, -np.inf), (None, -np.inf)],
#                      "PN": [(None, -np.inf), (None, -np.inf), (None, -np.inf)], 
#                      "MSA": [(None, -np.inf), (None, -np.inf), (None, -np.inf)]}

# FN_group_sample_counter = {"HC": 0, "RBD": 0, "PN": 0, "MSA": 0}
# top3_FN_per_group = {"HC": [(None, -np.inf), (None, -np.inf), (None, -np.inf)], 
#                      "RBD": [(None, -np.inf), (None, -np.inf), (None, -np.inf)],
#                      "PN": [(None, -np.inf), (None, -np.inf), (None, -np.inf)], 
#                      "MSA": [(None, -np.inf), (None, -np.inf), (None, -np.inf)]}

# folder_path = Path("praat_pitches/vowels")
# if folder_path.exists():
#     for subfolder in folder_path.iterdir():
#         if subfolder.is_dir():
            
#             group = subfolder.name
#             # TP_total = 0
#             # FP_total = 0
#             # FN_total = 0
#             for file_path in subfolder.iterdir():
                
#                 if file_path.is_file() and file_path.suffix == ".txt":
                    
                    
#                     sample_name = file_path.name[len("Pitch "):-4]
#                     sample_length = recording_lengths[sample_name]
#                     data = np.loadtxt(file_path, delimiter="\t")

#                     sample_labels = labels_intervals[sample_name] if sample_name in labels_intervals else []
#                     tmin_cutoff = 1.
#                     TP, FP, FN = detectSubharmonics(data, sample_labels, sample_length, tmin_cutoff)
#                     # if FP > 0:
#                     #     FP_group_sample_counter[group] += 1
                    
#                     # if FP > top3_FP_per_group[group][0][1]:
#                     #     top3_FP_per_group[group] = [(sample_name, FP), top3_FP_per_group[group][0], top3_FP_per_group[group][1]]
#                     # elif FP > top3_FP_per_group[group][1][1]:
#                     #     top3_FP_per_group[group] = [top3_FP_per_group[group][0], (sample_name, FP), top3_FP_per_group[group][1]]
#                     # elif FP > top3_FP_per_group[group][2][1]: 
#                     #     top3_FP_per_group[group][2] = (sample_name, FP)

#                     # if FN > 0:
#                     #     FN_group_sample_counter[group] += 1
                    
#                     # if FN > top3_FN_per_group[group][0][1]:
#                     #     top3_FN_per_group[group] = [(sample_name, FN), top3_FN_per_group[group][0], top3_FN_per_group[group][1]]
#                     # elif FN > top3_FN_per_group[group][1][1]:
#                     #     top3_FN_per_group[group] = [top3_FN_per_group[group][0], (sample_name, FN), top3_FN_per_group[group][1]]
#                     # elif FN > top3_FN_per_group[group][2][1]: 
#                     #     top3_FN_per_group[group][2] = (sample_name, FN)

#                     performance_metrics[group]["TP"] += TP
#                     performance_metrics[group]["FP"] += FP
#                     performance_metrics[group]["FN"] += FN

#             accuracy = getAccuracy(performance_metrics[group]["TP"], performance_metrics[group]["FP"], performance_metrics[group]["FN"])
#             performance_metrics[group]["accuracy"] = accuracy
#             precision = getPrecision(performance_metrics[group]["TP"], performance_metrics[group]["FP"])
#             performance_metrics[group]["precision"] = precision
#             recall = getRecall(performance_metrics[group]["TP"], performance_metrics[group]["FN"])
#             performance_metrics[group]["recall"] = recall
#             f1 = getF1(precision, recall)
#             performance_metrics[group]["f1"] = f1

# for g in performance_metrics:
#     if g != "overall":
#         performance_metrics["overall"]["TP"] += performance_metrics[g]["TP"]
#         performance_metrics["overall"]["FP"] += performance_metrics[g]["FP"]
#         performance_metrics["overall"]["FN"] += performance_metrics[g]["FN"]

# performance_metrics["overall"]["accuracy"] = getAccuracy(performance_metrics["overall"]["TP"], performance_metrics["overall"]["FP"], performance_metrics["overall"]["FN"])
# performance_metrics["overall"]["precision"] = getPrecision(performance_metrics["overall"]["TP"], performance_metrics["overall"]["FP"])
# performance_metrics["overall"]["recall"] = getRecall(performance_metrics["overall"]["TP"], performance_metrics["overall"]["FN"])
# performance_metrics["overall"]["f1"] = getF1(performance_metrics["overall"]["precision"], performance_metrics["overall"]["recall"])

# for g in performance_metrics:         
#     print(f"---------{g}---------")
#     print(f"TP for {g}:", performance_metrics[g]["TP"])
#     print(f"FP for {g}:", performance_metrics[g]["FP"])
#     print(f"FN for {g}:", performance_metrics[g]["FN"])
#     print(f"Accuracy for {g}: {performance_metrics[g]["accuracy"]:.3f}")
#     print(f"Precision for {g}: {performance_metrics[g]["precision"]:.3f}")
#     print(f"Recall for {g}: {performance_metrics[g]["recall"]:.3f}")
#     print(f"F1 for {g}: {performance_metrics[g]["f1"]:.3f}")

#     if g != "overall":
#         print(f"Samples with an FP: {FP_group_sample_counter[g]}")
#         for top in top3_FP_per_group[g]:
#             print(f"Sample {top[0]} with {top[1]} FPs")

#         print(f"Samples with an FN: {FN_group_sample_counter[g]}")
#         for top in top3_FN_per_group[g]:
#             print(f"Sample {top[0]} with {top[1]} FNs")

# %%
def runEpoch(win_len, fref_mode, min_gap, min_subharm_len):
    

    metrics = {"HC": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
                       "RBD": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
                       "PN": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
                       "MSA": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},
                       "overall": {"TP": 0, "FP": 0, "FN": 0, "accuracy": 0, "precision": 0, "recall": 0, "F1": 0},}

    folder_path = Path("praat_pitches/vowels")
    if folder_path.exists():
        for subfolder in folder_path.iterdir():
            if subfolder.is_dir():
                
                group = subfolder.name
                # TP_total = 0
                # FP_total = 0
                # FN_total = 0
                for file_path in subfolder.iterdir():
                    
                    if file_path.is_file() and file_path.suffix == ".txt":
                        
                        
                        sample_name = file_path.name[len("Pitch "):-4]
                        sample_length = recording_lengths[sample_name]
                        data = np.loadtxt(file_path, delimiter="\t")

                        sample_labels = labels_intervals[sample_name] if sample_name in labels_intervals else []
                        tmin_cutoff = 1.
                        TP, FP, FN = detectSubharmonics(data, sample_labels, sample_length, tmin_cutoff, win_len, fref_mode, min_gap, min_subharm_len)

                        metrics[group]["TP"] += TP
                        metrics[group]["FP"] += FP
                        metrics[group]["FN"] += FN

                accuracy = getAccuracy(metrics[group]["TP"], metrics[group]["FP"], metrics[group]["FN"])
                metrics[group]["accuracy"] = accuracy
                precision = getPrecision(metrics[group]["TP"], metrics[group]["FP"])
                metrics[group]["precision"] = precision
                recall = getRecall(metrics[group]["TP"], metrics[group]["FN"])
                metrics[group]["recall"] = recall
                f1 = getF1(precision, recall)
                metrics[group]["f1"] = f1

    for g in metrics:
        if g != "overall":
            metrics["overall"]["TP"] += metrics[g]["TP"]
            metrics["overall"]["FP"] += metrics[g]["FP"]
            metrics["overall"]["FN"] += metrics[g]["FN"]

    metrics["overall"]["accuracy"] = getAccuracy(metrics["overall"]["TP"], metrics["overall"]["FP"], metrics["overall"]["FN"])
    metrics["overall"]["precision"] = getPrecision(metrics["overall"]["TP"], metrics["overall"]["FP"])
    metrics["overall"]["recall"] = getRecall(metrics["overall"]["TP"], metrics["overall"]["FN"])
    metrics["overall"]["f1"] = getF1(metrics["overall"]["precision"], metrics["overall"]["recall"])

    return metrics

# %%
cutoffs = [1.0] #[0.8, 1.0, 1.2, 1.4, 1.6]
win_lengths = [0.15, 0.2, 0.25, 0.3, 0.35] # 0.1, 
fref_modes = ["upper_70_90_median", "upper_80_90_median"] # "upper_60_80_median", 
EM_subharm_priors = [0.1]#, 0.5]
merge_gaps = [0.3, 0.4, 0.5, 0.6, 0.7]
min_subharm_lengths = [0.05, 0.1, 0.15, 0.2]
iou_threshs = [0.3] # 0.2, 

bestAccuracy, bestPrecision, bestRecall, bestF1 = 0., 0., 0., 0.
bestAccuracyIdx, bestPrecisionIdx, bestRecallIdx, bestF1Idx = None, None, None, None
bestAccuracyParams, bestPrecisionParams, bestRecallParams, bestF1Params = None, None, None, None

nIterations = len(cutoffs)*len(win_lengths)*len(fref_modes)*len(EM_subharm_priors)*len(merge_gaps)*len(min_subharm_lengths)*len(iou_threshs)
print(f"Total number of iterations: {nIterations}")

iter_metrics = []

counter = 1
# for co in cutoffs:
for wl in win_lengths:
    for fm in fref_modes:
        # for sp in EM_subharm_priors:
        for mg in merge_gaps:
            for msl in min_subharm_lengths:
                # for iout in iou_threshs:
                print(f"Iteration {counter}/{nIterations} with win_len = {wl}, fref_mode = {fm}, merge_gap={mg}, min_subharm_len={msl}")
                metrics = runEpoch(wl, fm, mg, msl)
                print(f"Iteration finished: accuracy {metrics["overall"]["accuracy"]:.3f}, precision {metrics["overall"]["precision"]:.3f}, recall {metrics["overall"]["recall"]:.3f}, F1 {metrics["overall"]["f1"]:.3f}")
                iter_metrics.append(metrics)
                if metrics["overall"]["accuracy"] > bestAccuracy:
                    bestAccuracy = metrics["overall"]["accuracy"]
                    bestAccuracyIdx = counter-1
                    bestAccuracyParams = {"wl": wl, "fm": fm, "mg": mg, "msl": msl}
                    print(f"NEW BEST ACCURACY {bestAccuracy:.3f}: win_len={wl}, fref_mode={fm}, min_gap={mg}, min_subharm_len={msl}")

                if metrics["overall"]["precision"] > bestPrecision:
                    bestPrecision = metrics["overall"]["precision"]
                    bestPrecisionIdx = counter-1
                    bestPrecisionParams = {"wl": wl, "fm": fm, "mg": mg, "msl": msl}
                    print(f"NEW BEST PRECISION {bestPrecision:.3f}: win_len={wl}, fref_mode={fm}, min_gap={mg}, min_subharm_len={msl}")

                if metrics["overall"]["recall"] > bestRecall:
                    bestRecall = metrics["overall"]["recall"]
                    bestRecallIdx = counter-1
                    bestRecallParams = {"wl": wl, "fm": fm, "mg": mg, "msl": msl}
                    print(f"NEW BEST RECALL {bestRecall:.3f}: win_len={wl}, fref_mode={fm}, min_gap={mg}, min_subharm_len={msl}")

                if metrics["overall"]["f1"] > bestF1:
                    bestF1 = metrics["overall"]["f1"]
                    bestF1Idx = counter-1
                    bestF1Params = {"wl": wl, "fm": fm, "mg": mg, "msl": msl}
                    print(f"NEW BEST F1 {bestF1:.3f}: win_len={wl}, fref_mode={fm}, min_gap={mg}, min_subharm_len={msl}")
                
                print()
                counter += 1
                
            
        
 

                
print("--------------FINISHED---------------")
print()
print("BEST PERFOMANCE PARAMETERS:")
print()
print(f"Best accuracy {bestAccuracy:.3f}: win_len={bestAccuracyParams["wl"]}, fref_mode={bestAccuracyParams["fm"]}, min_gap={bestAccuracyParams["mg"]}, min_subharm_len={bestAccuracyParams["msl"]}")
bestAccuracyMetrics = iter_metrics[bestAccuracyIdx]
for g in bestAccuracyMetrics:         
    print(f"---------{g}---------")
    print(f"TP for {g}:", bestAccuracyMetrics[g]["TP"])
    print(f"FP for {g}:", bestAccuracyMetrics[g]["FP"])
    print(f"FN for {g}:", bestAccuracyMetrics[g]["FN"])
    print(f"Accuracy for {g}: {bestAccuracyMetrics[g]["accuracy"]:.3f}")
    print(f"Precision for {g}: {bestAccuracyMetrics[g]["precision"]:.3f}")
    print(f"Recall for {g}: {bestAccuracyMetrics[g]["recall"]:.3f}")
    print(f"F1 for {g}: {bestAccuracyMetrics[g]["f1"]:.3f}")
print()

print(f"Best precision {bestPrecision:.3f}: win_len={bestPrecisionParams["wl"]}, fref_mode={bestPrecisionParams["fm"]}, min_gap={bestPrecisionParams["mg"]}, min_subharm_len={bestPrecisionParams["msl"]}")
bestPrecisionMetrics = iter_metrics[bestPrecisionIdx]
for g in bestPrecisionMetrics:         
    print(f"---------{g}---------")
    print(f"TP for {g}:", bestPrecisionMetrics[g]["TP"])
    print(f"FP for {g}:", bestPrecisionMetrics[g]["FP"])
    print(f"FN for {g}:", bestPrecisionMetrics[g]["FN"])
    print(f"Accuracy for {g}: {bestPrecisionMetrics[g]["accuracy"]:.3f}")
    print(f"Precision for {g}: {bestPrecisionMetrics[g]["precision"]:.3f}")
    print(f"Recall for {g}: {bestPrecisionMetrics[g]["recall"]:.3f}")
    print(f"F1 for {g}: {bestPrecisionMetrics[g]["f1"]:.3f}")
print()

print(f"Best recall {bestRecall:.3f}: win_len={bestRecallParams["wl"]}, fref_mode={bestRecallParams["fm"]}, min_gap={bestRecallParams["mg"]}, min_subharm_len={bestRecallParams["msl"]}")
bestRecallMetrics = iter_metrics[bestRecallIdx]
for g in bestRecallMetrics:         
    print(f"---------{g}---------")
    print(f"TP for {g}:", bestRecallMetrics[g]["TP"])
    print(f"FP for {g}:", bestRecallMetrics[g]["FP"])
    print(f"FN for {g}:", bestRecallMetrics[g]["FN"])
    print(f"Accuracy for {g}: {bestRecallMetrics[g]["accuracy"]:.3f}")
    print(f"Precision for {g}: {bestRecallMetrics[g]["precision"]:.3f}")
    print(f"Recall for {g}: {bestRecallMetrics[g]["recall"]:.3f}")
    print(f"F1 for {g}: {bestRecallMetrics[g]["f1"]:.3f}")
print()

print(f"Best F1 {bestF1:.3f}: win_len={bestF1Params["wl"]}, fref_mode={bestF1Params["fm"]}, min_gap={bestF1Params["mg"]}, min_subharm_len={bestF1Params["msl"]}")
bestF1Metrics = iter_metrics[bestF1Idx]
for g in bestF1Metrics:         
    print(f"---------{g}---------")
    print(f"TP for {g}:", bestF1Metrics[g]["TP"])
    print(f"FP for {g}:", bestF1Metrics[g]["FP"])
    print(f"FN for {g}:", bestF1Metrics[g]["FN"])
    print(f"Accuracy for {g}: {bestF1Metrics[g]["accuracy"]:.3f}")
    print(f"Precision for {g}: {bestF1Metrics[g]["precision"]:.3f}")
    print(f"Recall for {g}: {bestF1Metrics[g]["recall"]:.3f}")
    print(f"F1 for {g}: {bestF1Metrics[g]["f1"]:.3f}")
# Out:
# Total number of iterations: 200
# Iteration 1/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.371, precision 0.498, recall 0.591, F1 0.541
# NEW BEST ACCURACY 0.371: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
# NEW BEST PRECISION 0.498: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
# NEW BEST RECALL 0.591: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
# NEW BEST F1 0.541: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 2/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.361, precision 0.586, recall 0.485, F1 0.531
# NEW BEST PRECISION 0.586: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.1
#
# Iteration 3/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.284, precision 0.579, recall 0.357, F1 0.442
#
# Iteration 4/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.210, precision 0.553, recall 0.253, F1 0.347
#
# Iteration 5/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.371, precision 0.510, recall 0.577, F1 0.541
# NEW BEST ACCURACY 0.371: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.4, min_subharm_len=0.05
# NEW BEST F1 0.541: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.4, min_subharm_len=0.05
#
# Iteration 6/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.359, precision 0.584, recall 0.483, F1 0.529
#
# Iteration 7/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.285, precision 0.570, recall 0.364, F1 0.444
#
# Iteration 8/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.218, precision 0.536, recall 0.268, F1 0.357
#
# Iteration 9/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.382, precision 0.530, recall 0.577, F1 0.552
# NEW BEST ACCURACY 0.382: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.5, min_subharm_len=0.05
# NEW BEST F1 0.552: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.5, min_subharm_len=0.05
#
# Iteration 10/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.359, precision 0.584, recall 0.483, F1 0.529
#
# Iteration 11/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.284, precision 0.560, recall 0.366, F1 0.443
#
# Iteration 12/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.217, precision 0.518, recall 0.272, F1 0.357
#
# Iteration 13/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.357, precision 0.522, recall 0.530, F1 0.526
#
# Iteration 14/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.330, precision 0.569, recall 0.440, F1 0.496
#
# Iteration 15/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.256, precision 0.538, recall 0.328, F1 0.407
#
# Iteration 16/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.199, precision 0.496, recall 0.249, F1 0.331
#
# Iteration 17/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.333, precision 0.508, recall 0.491, F1 0.499
#
# Iteration 18/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.308, precision 0.545, recall 0.415, F1 0.471
#
# Iteration 19/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.235, precision 0.507, recall 0.304, F1 0.380
#
# Iteration 20/200 with win_len = 0.15, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.188, precision 0.469, recall 0.238, F1 0.316
#
# Iteration 21/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.322, precision 0.413, recall 0.594, F1 0.487
# NEW BEST RECALL 0.594: win_len=0.15, fref_mode=upper_80_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 22/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.357, precision 0.573, recall 0.487, F1 0.526
#
# Iteration 23/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.281, precision 0.563, recall 0.360, F1 0.439
#
# Iteration 24/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.212, precision 0.548, recall 0.257, F1 0.350
#
# Iteration 25/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.340, precision 0.449, recall 0.583, F1 0.507
#
# Iteration 26/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.360, precision 0.576, recall 0.489, F1 0.529
#
# Iteration 27/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.285, precision 0.558, recall 0.368, F1 0.444
#
# Iteration 28/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.222, precision 0.540, recall 0.274, F1 0.364
#
# Iteration 29/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.354, precision 0.479, recall 0.577, F1 0.523
#
# Iteration 30/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.355, precision 0.573, recall 0.483, F1 0.524
#
# Iteration 31/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.282, precision 0.550, recall 0.366, F1 0.439
#
# Iteration 32/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.219, precision 0.520, recall 0.274, F1 0.359
#
# Iteration 33/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.333, precision 0.474, recall 0.528, F1 0.499
#
# Iteration 34/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.325, precision 0.557, recall 0.438, F1 0.490
#
# Iteration 35/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.251, precision 0.524, recall 0.326, F1 0.402
#
# Iteration 36/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.198, precision 0.492, recall 0.249, F1 0.331
#
# Iteration 37/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.314, precision 0.467, recall 0.489, F1 0.478
#
# Iteration 38/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.303, precision 0.533, recall 0.413, F1 0.465
#
# Iteration 39/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.231, precision 0.493, recall 0.302, F1 0.375
#
# Iteration 40/200 with win_len = 0.15, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.187, precision 0.465, recall 0.238, F1 0.315
#
# Iteration 41/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.328, precision 0.420, recall 0.600, F1 0.494
# NEW BEST RECALL 0.600: win_len=0.2, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 42/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.366, precision 0.586, recall 0.494, F1 0.536
#
# Iteration 43/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.289, precision 0.579, recall 0.366, F1 0.449
#
# Iteration 44/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.217, precision 0.549, recall 0.264, F1 0.356
#
# Iteration 45/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.348, precision 0.459, recall 0.589, F1 0.516
#
# Iteration 46/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.367, precision 0.585, recall 0.496, F1 0.537
#
# Iteration 47/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.291, precision 0.568, recall 0.374, F1 0.451
#
# Iteration 48/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.226, precision 0.537, recall 0.281, F1 0.369
#
# Iteration 49/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.355, precision 0.480, recall 0.577, F1 0.524
#
# Iteration 50/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.356, precision 0.575, recall 0.483, F1 0.525
#
# Iteration 51/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.282, precision 0.551, recall 0.366, F1 0.440
#
# Iteration 52/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.218, precision 0.514, recall 0.274, F1 0.358
#
# Iteration 53/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.333, precision 0.475, recall 0.528, F1 0.500
#
# Iteration 54/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.323, precision 0.551, recall 0.438, F1 0.488
#
# Iteration 55/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.250, precision 0.519, recall 0.326, F1 0.400
#
# Iteration 56/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.195, precision 0.476, recall 0.249, F1 0.327
#
# Iteration 57/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.315, precision 0.467, recall 0.491, F1 0.479
#
# Iteration 58/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.305, precision 0.534, recall 0.415, F1 0.467
#
# Iteration 59/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.233, precision 0.497, recall 0.304, F1 0.377
#
# Iteration 60/200 with win_len = 0.2, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.187, precision 0.459, recall 0.240, F1 0.316
#
# Iteration 61/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.332, precision 0.422, recall 0.609, F1 0.498
# NEW BEST RECALL 0.609: win_len=0.2, fref_mode=upper_80_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 62/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.365, precision 0.568, recall 0.504, F1 0.534
#
# Iteration 63/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.288, precision 0.555, recall 0.374, F1 0.447
#
# Iteration 64/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.218, precision 0.522, recall 0.272, F1 0.358
#
# Iteration 65/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.347, precision 0.456, recall 0.594, F1 0.516
#
# Iteration 66/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.366, precision 0.574, recall 0.502, F1 0.536
#
# Iteration 67/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.292, precision 0.554, recall 0.381, F1 0.451
#
# Iteration 68/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.228, precision 0.527, recall 0.287, F1 0.372
#
# Iteration 69/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.351, precision 0.472, recall 0.577, F1 0.519
#
# Iteration 70/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.351, precision 0.560, recall 0.485, F1 0.520
#
# Iteration 71/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.277, precision 0.533, recall 0.366, F1 0.434
#
# Iteration 72/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.215, precision 0.496, recall 0.274, F1 0.353
#
# Iteration 73/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.327, precision 0.464, recall 0.526, F1 0.493
#
# Iteration 74/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.317, precision 0.535, recall 0.438, F1 0.482
#
# Iteration 75/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.244, precision 0.497, recall 0.323, F1 0.392
#
# Iteration 76/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.191, precision 0.458, recall 0.247, F1 0.321
#
# Iteration 77/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.309, precision 0.455, recall 0.489, F1 0.472
#
# Iteration 78/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.300, precision 0.519, recall 0.415, F1 0.461
#
# Iteration 79/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.226, precision 0.475, recall 0.302, F1 0.369
#
# Iteration 80/200 with win_len = 0.2, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.183, precision 0.443, recall 0.238, F1 0.310
#
# Iteration 81/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.340, precision 0.434, recall 0.611, F1 0.507
# NEW BEST RECALL 0.611: win_len=0.25, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 82/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.374, precision 0.588, recall 0.506, F1 0.544
# NEW BEST PRECISION 0.588: win_len=0.25, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.1
#
# Iteration 83/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.295, precision 0.578, recall 0.377, F1 0.456
#
# Iteration 84/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.222, precision 0.537, recall 0.274, F1 0.363
#
# Iteration 85/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.351, precision 0.461, recall 0.594, F1 0.519
#
# Iteration 86/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.370, precision 0.584, recall 0.502, F1 0.540
#
# Iteration 87/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.294, precision 0.567, recall 0.379, F1 0.454
#
# Iteration 88/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.227, precision 0.525, recall 0.285, F1 0.370
#
# Iteration 89/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.352, precision 0.476, recall 0.574, F1 0.521
#
# Iteration 90/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.354, precision 0.569, recall 0.483, F1 0.522
#
# Iteration 91/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.278, precision 0.541, recall 0.364, F1 0.435
#
# Iteration 92/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.213, precision 0.494, recall 0.272, F1 0.351
#
# Iteration 93/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.329, precision 0.468, recall 0.526, F1 0.495
#
# Iteration 94/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.320, precision 0.544, recall 0.438, F1 0.485
#
# Iteration 95/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.246, precision 0.508, recall 0.323, F1 0.395
#
# Iteration 96/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.192, precision 0.462, recall 0.247, F1 0.322
#
# Iteration 97/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.311, precision 0.460, recall 0.489, F1 0.474
#
# Iteration 98/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.302, precision 0.527, recall 0.415, F1 0.464
#
# Iteration 99/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.229, precision 0.486, recall 0.302, F1 0.373
#
# Iteration 100/200 with win_len = 0.25, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.184, precision 0.444, recall 0.238, F1 0.310
#
# Iteration 101/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.351, precision 0.442, recall 0.630, F1 0.520
# NEW BEST RECALL 0.630: win_len=0.25, fref_mode=upper_80_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 102/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.374, precision 0.568, recall 0.523, F1 0.545
#
# Iteration 103/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.301, precision 0.564, recall 0.391, F1 0.462
#
# Iteration 104/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.229, precision 0.523, recall 0.289, F1 0.373
#
# Iteration 105/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.356, precision 0.465, recall 0.604, F1 0.525
#
# Iteration 106/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.366, precision 0.563, recall 0.511, F1 0.536
#
# Iteration 107/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.291, precision 0.545, recall 0.385, F1 0.451
#
# Iteration 108/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.229, precision 0.509, recall 0.294, F1 0.372
#
# Iteration 109/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.356, precision 0.478, recall 0.583, F1 0.525
#
# Iteration 110/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.350, precision 0.552, recall 0.489, F1 0.519
#
# Iteration 111/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.275, precision 0.520, recall 0.368, F1 0.431
#
# Iteration 112/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.213, precision 0.476, recall 0.279, F1 0.352
#
# Iteration 113/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.332, precision 0.470, recall 0.530, F1 0.498
#
# Iteration 114/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.317, precision 0.528, recall 0.443, F1 0.481
#
# Iteration 115/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.242, precision 0.487, recall 0.326, F1 0.390
#
# Iteration 116/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.191, precision 0.445, recall 0.251, F1 0.321
#
# Iteration 117/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.308, precision 0.454, recall 0.489, F1 0.471
#
# Iteration 118/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.296, precision 0.509, recall 0.415, F1 0.457
#
# Iteration 119/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.224, precision 0.464, recall 0.302, F1 0.366
#
# Iteration 120/200 with win_len = 0.25, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.182, precision 0.428, recall 0.240, F1 0.308
#
# Iteration 121/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.357, precision 0.451, recall 0.632, F1 0.526
# NEW BEST RECALL 0.632: win_len=0.3, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 122/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.380, precision 0.580, recall 0.523, F1 0.550
#
# Iteration 123/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.307, precision 0.584, recall 0.394, F1 0.470
#
# Iteration 124/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.236, precision 0.552, recall 0.291, F1 0.382
#
# Iteration 125/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.363, precision 0.474, recall 0.609, F1 0.533
#
# Iteration 126/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.373, precision 0.578, recall 0.513, F1 0.543
#
# Iteration 127/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.299, precision 0.563, recall 0.389, F1 0.460
#
# Iteration 128/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.236, precision 0.534, recall 0.298, F1 0.383
#
# Iteration 129/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.360, precision 0.483, recall 0.585, F1 0.529
#
# Iteration 130/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.355, precision 0.564, recall 0.489, F1 0.524
#
# Iteration 131/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.280, precision 0.535, recall 0.370, F1 0.438
#
# Iteration 132/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.219, precision 0.498, recall 0.281, F1 0.359
#
# Iteration 133/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.335, precision 0.475, recall 0.532, F1 0.502
#
# Iteration 134/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.321, precision 0.540, recall 0.443, F1 0.487
#
# Iteration 135/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.247, precision 0.502, recall 0.328, F1 0.396
#
# Iteration 136/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.196, precision 0.465, recall 0.253, F1 0.328
#
# Iteration 137/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.311, precision 0.458, recall 0.491, F1 0.474
#
# Iteration 138/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.300, precision 0.520, recall 0.415, F1 0.462
#
# Iteration 139/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.228, precision 0.478, recall 0.304, F1 0.372
#
# Iteration 140/200 with win_len = 0.3, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.186, precision 0.445, recall 0.243, F1 0.314
#
# Iteration 141/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.365, precision 0.458, recall 0.643, F1 0.535
# NEW BEST RECALL 0.643: win_len=0.3, fref_mode=upper_80_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 142/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.327, precision 0.457, recall 0.536, F1 0.493
#
# Iteration 143/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.312, precision 0.578, recall 0.404, F1 0.476
#
# Iteration 144/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.241, precision 0.546, recall 0.302, F1 0.389
#
# Iteration 145/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.366, precision 0.477, recall 0.611, F1 0.535
#
# Iteration 146/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.332, precision 0.480, recall 0.517, F1 0.498
#
# Iteration 147/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.297, precision 0.547, recall 0.394, F1 0.458
#
# Iteration 148/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.236, precision 0.518, recall 0.302, F1 0.382
#
# Iteration 149/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.362, precision 0.485, recall 0.587, F1 0.531
#
# Iteration 150/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.323, precision 0.483, recall 0.494, F1 0.488
#
# Iteration 151/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.278, precision 0.524, recall 0.372, F1 0.435
#
# Iteration 152/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.217, precision 0.484, recall 0.283, F1 0.357
#
# Iteration 153/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.335, precision 0.474, recall 0.532, F1 0.502
#
# Iteration 154/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.295, precision 0.470, recall 0.443, F1 0.456
#
# Iteration 155/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.244, precision 0.490, recall 0.328, F1 0.393
#
# Iteration 156/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.193, precision 0.451, recall 0.253, F1 0.324
#
# Iteration 157/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.311, precision 0.458, recall 0.491, F1 0.474
#
# Iteration 158/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.278, precision 0.458, recall 0.415, F1 0.435
#
# Iteration 159/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.226, precision 0.469, recall 0.304, F1 0.369
#
# Iteration 160/200 with win_len = 0.3, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.184, precision 0.433, recall 0.243, F1 0.311
#
# Iteration 161/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.361, precision 0.453, recall 0.640, F1 0.531
#
# Iteration 162/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.324, precision 0.453, recall 0.532, F1 0.489
#
# Iteration 163/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.308, precision 0.573, recall 0.400, F1 0.471
#
# Iteration 164/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.238, precision 0.543, recall 0.298, F1 0.385
#
# Iteration 165/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.364, precision 0.474, recall 0.611, F1 0.534
#
# Iteration 166/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.332, precision 0.480, recall 0.517, F1 0.498
#
# Iteration 167/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.297, precision 0.549, recall 0.394, F1 0.458
#
# Iteration 168/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.235, precision 0.516, recall 0.302, F1 0.381
#
# Iteration 169/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.362, precision 0.483, recall 0.589, F1 0.531
#
# Iteration 170/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.325, precision 0.484, recall 0.496, F1 0.490
#
# Iteration 171/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.280, precision 0.525, recall 0.374, F1 0.437
#
# Iteration 172/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.218, precision 0.480, recall 0.285, F1 0.358
#
# Iteration 173/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.332, precision 0.470, recall 0.532, F1 0.499
#
# Iteration 174/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.294, precision 0.467, recall 0.443, F1 0.455
#
# Iteration 175/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.244, precision 0.489, recall 0.328, F1 0.392
#
# Iteration 176/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.192, precision 0.444, recall 0.253, F1 0.322
#
# Iteration 177/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.309, precision 0.454, recall 0.491, F1 0.472
#
# Iteration 178/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.277, precision 0.455, recall 0.415, F1 0.434
#
# Iteration 179/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.226, precision 0.466, recall 0.304, F1 0.368
#
# Iteration 180/200 with win_len = 0.35, fref_mode = upper_70_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.183, precision 0.427, recall 0.243, F1 0.309
#
# Iteration 181/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.05
# Iteration finished: accuracy 0.379, precision 0.472, recall 0.660, F1 0.550
# NEW BEST RECALL 0.660: win_len=0.35, fref_mode=upper_80_90_median, min_gap=0.3, min_subharm_len=0.05
#
# Iteration 182/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.1
# Iteration finished: accuracy 0.339, precision 0.466, recall 0.553, F1 0.506
#
# Iteration 183/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.15
# Iteration finished: accuracy 0.320, precision 0.574, recall 0.419, F1 0.485
#
# Iteration 184/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.3, min_subharm_len=0.2
# Iteration finished: accuracy 0.253, precision 0.551, recall 0.319, F1 0.404
#
# Iteration 185/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.05
# Iteration finished: accuracy 0.368, precision 0.478, recall 0.615, F1 0.538
#
# Iteration 186/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.1
# Iteration finished: accuracy 0.329, precision 0.472, recall 0.521, F1 0.495
#
# Iteration 187/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.15
# Iteration finished: accuracy 0.292, precision 0.532, recall 0.394, F1 0.452
#
# Iteration 188/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.4, min_subharm_len=0.2
# Iteration finished: accuracy 0.232, precision 0.500, recall 0.302, F1 0.377
#
# Iteration 189/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.05
# Iteration finished: accuracy 0.363, precision 0.486, recall 0.589, F1 0.533
#
# Iteration 190/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.1
# Iteration finished: accuracy 0.321, precision 0.476, recall 0.496, F1 0.486
#
# Iteration 191/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.15
# Iteration finished: accuracy 0.273, precision 0.507, recall 0.372, F1 0.429
#
# Iteration 192/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.5, min_subharm_len=0.2
# Iteration finished: accuracy 0.213, precision 0.463, recall 0.283, F1 0.351
#
# Iteration 193/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.05
# Iteration finished: accuracy 0.332, precision 0.470, recall 0.530, F1 0.498
#
# Iteration 194/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.1
# Iteration finished: accuracy 0.290, precision 0.458, recall 0.440, F1 0.449
#
# Iteration 195/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.15
# Iteration finished: accuracy 0.237, precision 0.472, recall 0.323, F1 0.384
#
# Iteration 196/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.6, min_subharm_len=0.2
# Iteration finished: accuracy 0.187, precision 0.429, recall 0.249, F1 0.315
#
# Iteration 197/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.05
# Iteration finished: accuracy 0.307, precision 0.453, recall 0.489, F1 0.470
#
# Iteration 198/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.1
# Iteration finished: accuracy 0.272, precision 0.445, recall 0.413, F1 0.428
#
# Iteration 199/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.15
# Iteration finished: accuracy 0.219, precision 0.449, recall 0.300, F1 0.360
#
# Iteration 200/200 with win_len = 0.35, fref_mode = upper_80_90_median, merge_gap=0.7, min_subharm_len=0.2
# Iteration finished: accuracy 0.178, precision 0.412, recall 0.238, F1 0.302
#
# --------------FINISHED---------------
#
# BEST PERFOMANCE PARAMETERS:
#
# Best accuracy 0.382: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.5, min_subharm_len=0.05
# ---------HC---------
# TP for HC: 53
# FP for HC: 73
# FN for HC: 31
# Accuracy for HC: 0.338
# Precision for HC: 0.421
# Recall for HC: 0.631
# F1 for HC: 0.505
# ---------RBD---------
# TP for RBD: 38
# FP for RBD: 26
# FN for RBD: 6
# Accuracy for RBD: 0.543
# Precision for RBD: 0.594
# Recall for RBD: 0.864
# F1 for RBD: 0.704
# ---------PN---------
# TP for PN: 79
# FP for PN: 60
# FN for PN: 65
# Accuracy for PN: 0.387
# Precision for PN: 0.568
# Recall for PN: 0.549
# F1 for PN: 0.558
# ---------MSA---------
# TP for MSA: 101
# FP for MSA: 81
# FN for MSA: 97
# Accuracy for MSA: 0.362
# Precision for MSA: 0.555
# Recall for MSA: 0.510
# F1 for MSA: 0.532
# ---------overall---------
# TP for overall: 271
# FP for overall: 240
# FN for overall: 199
# Accuracy for overall: 0.382
# Precision for overall: 0.530
# Recall for overall: 0.577
# F1 for overall: 0.552
#
# Best precision 0.588: win_len=0.25, fref_mode=upper_70_90_median, min_gap=0.3, min_subharm_len=0.1
# ---------HC---------
# TP for HC: 50
# FP for HC: 60
# FN for HC: 34
# Accuracy for HC: 0.347
# Precision for HC: 0.455
# Recall for HC: 0.595
# F1 for HC: 0.515
# ---------RBD---------
# TP for RBD: 29
# FP for RBD: 16
# FN for RBD: 15
# Accuracy for RBD: 0.483
# Precision for RBD: 0.644
# Recall for RBD: 0.659
# F1 for RBD: 0.652
# ---------PN---------
# TP for PN: 66
# FP for PN: 37
# FN for PN: 78
# Accuracy for PN: 0.365
# Precision for PN: 0.641
# Recall for PN: 0.458
# F1 for PN: 0.534
# ---------MSA---------
# TP for MSA: 93
# FP for MSA: 54
# FN for MSA: 105
# Accuracy for MSA: 0.369
# Precision for MSA: 0.633
# Recall for MSA: 0.470
# F1 for MSA: 0.539
# ---------overall---------
# TP for overall: 238
# FP for overall: 167
# FN for overall: 232
# Accuracy for overall: 0.374
# Precision for overall: 0.588
# Recall for overall: 0.506
# F1 for overall: 0.544
#
# Best recall 0.660: win_len=0.35, fref_mode=upper_80_90_median, min_gap=0.3, min_subharm_len=0.05
# ---------HC---------
# TP for HC: 62
# FP for HC: 104
# FN for HC: 22
# Accuracy for HC: 0.330
# Precision for HC: 0.373
# Recall for HC: 0.738
# F1 for HC: 0.496
# ---------RBD---------
# TP for RBD: 39
# FP for RBD: 29
# FN for RBD: 5
# Accuracy for RBD: 0.534
# Precision for RBD: 0.574
# Recall for RBD: 0.886
# F1 for RBD: 0.696
# ---------PN---------
# TP for PN: 84
# FP for PN: 102
# FN for PN: 60
# Accuracy for PN: 0.341
# Precision for PN: 0.452
# Recall for PN: 0.583
# F1 for PN: 0.509
# ---------MSA---------
# TP for MSA: 125
# FP for MSA: 112
# FN for MSA: 73
# Accuracy for MSA: 0.403
# Precision for MSA: 0.527
# Recall for MSA: 0.631
# F1 for MSA: 0.575
# ---------overall---------
# TP for overall: 310
# FP for overall: 347
# FN for overall: 160
# Accuracy for overall: 0.379
# Precision for overall: 0.472
# Recall for overall: 0.660
# F1 for overall: 0.550
#
# Best F1 0.552: win_len=0.15, fref_mode=upper_70_90_median, min_gap=0.5, min_subharm_len=0.05
# ---------HC---------
# TP for HC: 53
# FP for HC: 73
# FN for HC: 31
# Accuracy for HC: 0.338
# Precision for HC: 0.421
# Recall for HC: 0.631
# F1 for HC: 0.505
# ---------RBD---------
# TP for RBD: 38
# FP for RBD: 26
# FN for RBD: 6
# Accuracy for RBD: 0.543
# Precision for RBD: 0.594
# Recall for RBD: 0.864
# F1 for RBD: 0.704
# ---------PN---------
# TP for PN: 79
# FP for PN: 60
# FN for PN: 65
# Accuracy for PN: 0.387
# Precision for PN: 0.568
# Recall for PN: 0.549
# F1 for PN: 0.558
# ---------MSA---------
# TP for MSA: 101
# FP for MSA: 81
# FN for MSA: 97
# Accuracy for MSA: 0.362
# Precision for MSA: 0.555
# Recall for MSA: 0.510
# F1 for MSA: 0.532
# ---------overall---------
# TP for overall: 271
# FP for overall: 240
# FN for overall: 199
# Accuracy for overall: 0.382
# Precision for overall: 0.530
# Recall for overall: 0.577
# F1 for overall: 0.552

# %%
# Sample HC845i2 with 7 FPs
# Sample HC592i1 with 5 FPs
# Sample HC861a2 with 4 FPs
# Samples with an FN: 13
# Sample HC592i1 with 5 FNs
# Sample HC853i2 with 5 FNs
# Sample HC836i2 with 4 FNs

# Sample RBD204i1 with 5 FPs
# Sample RBD114a1 with 4 FPs
# Sample RBD130a1 with 3 FPs
# Samples with an FN: 5
# Sample RBD223a1 with 2 FNs
# Sample RBD114i1 with 1 FNs
# Sample RBD134i2 with 1 FNs

data = np.loadtxt("praat_pitches/vowels/HC/Pitch HC853i2.txt", delimiter="\t")

times = data[:, 0]
pitch = data[:, 1]
pitch = interpolate_pitch(pitch)
plt.figure()
plt.plot(times, pitch)
plt.show()

if len(times) != len(pitch):
    raise IndexError("Time indeces don't match pitch values!")

time_step = np.round(np.median(np.diff(times)), 4)
print(f"Time step: {time_step}")

win_len = 0.25 # 250 ms
n_side = int(round((win_len / 2) / time_step))
first_frame_idx = n_side # frame_idx = np.searchsorted(times, times[0] + win_len/2)
last_frame_idx = len(pitch) - n_side -1
# win_size = 2*n_side + 1

x_frames = []
for frame_idx in range(first_frame_idx, last_frame_idx+1):
    x_t = getFrameXt(pitch, frame_idx, n_side, fref_mode="upper_median")
    if x_t is None:
        print("NONE")
    x_frames.append(x_t)

time_frames = times[first_frame_idx:last_frame_idx+1]

# plt.figure()
# plt.plot(time_frames, x_frames)
# plt.ylim((-1.1, 0.1))
# plt.show()

x_frames = np.array(x_frames)
em = em_two_fixed_means(x_frames)

# # print("Estimated parameters:")
# # print(f"prior_non  = {em['prior_non']:.3f}")
# # print(f"prior_sub  = {em['prior_sub']:.3f}")
# # print(f"sigma_non = {em['sigma_non']:.3f}")
# # print(f"sigma_sub = {em['sigma_sub']:.3f}")



# Min subharm length: 0.049 seconds
# Min inter-subharm interval: 0.066 seconds

time_step = np.median(np.diff(time_frames))
print(f"time_step = {time_step:.4f} s")

min_subharm_dur = 0.05
max_gap_dur = 0.5

min_len_frames = int(np.ceil(min_subharm_dur / time_step))
max_gap_frames = int(np.floor(max_gap_dur / time_step))
print(f"min_len_frames = {min_len_frames}")
print(f"max_gap_frames = {max_gap_frames}")

decision_thresh = 0.5
labels_sub = (em["posterior_sub"] >= decision_thresh)
print(labels_sub.sum())

smooth_span_sec = 0.05
smooth_win_len = int(round(smooth_span_sec / time_step))
if smooth_win_len % 2 == 0:
    smooth_win_len += 1
smooth_win_len = max(smooth_win_len, 1)
print(f"Smooth win len for 50ms: {smooth_win_len} frames")

print(em["posterior_sub"].shape)
posterior_smoothed = smooth_posterior(em["posterior_sub"], win_len)
print(posterior_smoothed.shape)
print(time_frames.shape)
labels_sub = (posterior_smoothed >= decision_thresh)
print(labels_sub.sum())

labels_sub = fill_short_gaps(labels_sub, max_gap_frames)
print(f"After 1st gap filling: {np.sum(labels_sub)}")
labels_sub = remove_short_subharmonic_runs(labels_sub, min_len_frames)
print(f"After removing short runs: {np.sum(labels_sub)}")
labels_sub = fill_short_gaps(labels_sub, max_gap_frames)
print(f"After 2nd gap filling: {np.sum(labels_sub)}")

intervals = labels_to_intervals(time_frames, labels_sub)
print(f"Total number of subharmonic intervals: {len(intervals)}")

gaps = [intervals[i+1][0] - intervals[i][1] for i in range(len(intervals)-1)]
print("Inter-subharmonic gaps [s]: ")
for g in gaps:
    print(g)

plt.figure(figsize=(12, 6))

plt.subplot(3, 1, 1)
plt.plot(time_frames, x_frames)
plt.title("x_t")
plt.ylim([-1.1, 0.1])
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(time_frames, em["posterior_sub"], label="raw posterior")
plt.plot(time_frames, posterior_smoothed, label="smoothed posterior")
plt.axhline(y=decision_thresh, linestyle='--', color='k', label='threshold')
plt.title("Subharmonic posterior")
plt.legend()
plt.ylim([-0.1, 1.1])
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(time_frames, labels_sub.astype(int))
plt.title("Final binary labels")
plt.ylim([-0.1, 1.1])
plt.grid(True)

for s, e in intervals:
    plt.subplot(3, 1, 1)
    plt.axvline(x=s, linestyle='--', color='r')
    plt.axvline(x=e, linestyle='--', color='b')

    plt.subplot(3, 1, 2)
    plt.axvline(x=s, linestyle='--', color='r')
    plt.axvline(x=e, linestyle='--', color='b')

    plt.subplot(3, 1, 3)
    plt.axvline(x=s, linestyle='--', color='r')
    plt.axvline(x=e, linestyle='--', color='b')

plt.tight_layout()
plt.show()
# Out:
# Time step: 0.0125
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[222], line 40
#      38 x_frames = []
#      39 for frame_idx in range(first_frame_idx, last_frame_idx+1):
# ---> 40     x_t = getFrameXt(pitch, frame_idx, n_side, fref_mode="upper_median")
#      41     if x_t is None:
#      42         print("NONE")
#
# Cell In[212], line 51, in getFrameXt(pitch, frame_idx, n_side, fref_mode)
#      49     fref = np.median(window_pitch_valid)
#      50 else:
# ---> 51     raise ValueError("Unsupported fref_mode")
#      53 # print(f"f_ref = {fref}")
#      54 if not np.isfinite(fref) or fref <= 0:
#
# ValueError: Unsupported fref_mode

# %%
accuracy = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0.0
precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

print("TP:", tp)
print("FP:", fp)
print("FN:", fn)
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1:", f1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 accuracy = tp / (tp + fp + fn) if (tp + fp + fn) > 0 else 0.0
#       2 precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
#       3 recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
#
# NameError: name 'tp' is not defined
